# %%
#program
import numpy as np
ar1=np.array([1,1,1,1,1,1,1,1,1])
mean=np.mean(ar1)
print("the original array is",ar1)
print("the mean of the given array is:",mean)
# Out:
# the original array is [1 1 1 1 1 1 1 1 1]
# the mean of the given array is: 1.0

# %%
#program
#median
import numpy as np
ar2=np.array([12,13,14,15,16,17,18,19,20])
median=np.median(ar2)
print("the original array is",ar2)
print("the median of the given array is:",median)
# Out:
# the original array is [12 13 14 15 16 17 18 19 20]
# the median of the given array is: 16.0

# %%
#program
#mode
import statistics as st
import numpy as np
ar3=np.array([10,20,30,40,50,60,10,10,100])
md=st.mode(ar3)
print("the original array is",ar3)
print("\n")
print("the mode of the given array is:",md)
# Out:
# the original array is [ 10  20  30  40  50  60  10  10 100]
#
#
# the mode of the given array is: 10

# %%
#program
#S.D
#Higher the S.D
ar4=np.array([17,16,17,14,13,17])
sd=np.std(ar4)
m1=np.mean(ar4)
print("the original array is",ar4)
print("\n")
print("the mean of the array is:",m1)
print("the calculated value of s.Dis:",sd)
# Out:
# the original array is [17 16 17 14 13 17]
#
#
# the mean of the array is: 15.666666666666666
# the calculated value of s.Dis: 1.5986105077709065

# %%
#program
per=np.array([10,14,15,17,45,50,55,60,80,100,33,63,72])
#find out 75 percentile of the data
a=np.percentile(per,75)
print(a)
# Out:
# 63.0

# %% [markdown]
# # 14 AUGUST 2026

# %%
from numpy import random
#Genrate  some random (Normalized)distribution of size 1x100
x=random.normal(size=(2,3))
print(x)
# Out:
# [[-0.8777485   0.34070219 -2.80753938]
#  [ 1.41458045  1.8741812   1.08869324]]

# %%
#NORMAL DIST,Mean=0
# curve=bell shaped curve
from numpy import random
# random function which is used to generate random data
import matplotlib.pyplot as plt
#from matplotlib import pylot only and as a plt alis.
import seaborn as sns
#shift+enter

# %%
#mean=1 and std=2
x=random.normal(loc=1,scale=2,size=(2,3))
#variable=random(function->random_data)->normal(mean,std,size)
print(x)
# Out:
# [[ 0.59835832  2.95717751  3.97889234]
#  [-0.04025557  2.70184441  0.04753128]]

# %%
# %pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from numpy import random
sns.displot(random.normal(size=1000),kind="kde")
plt.show()

# %%
sns.displot(random.normal(size=1000))
plt.show()

# %% [markdown]
# BINOMIAL DISTRIBUTION

# %%
# random.binomial(n,p,size=None)
#p=probability
#size=the size of the returned array
from numpy import random
x=random.binomial(n=10,p=0.5,size=10)
print(x)
# Out:
# [7 4 5 5 4 2 3 6 4 4]

# %%
sns.displot(random.binomial(n=10,p=0.7,size=10),kde=False)
plt.show()

# %%
#poisson distribution
# IF ANY EVENT HAS ALREADY OCCURED FOR X TIME THEN WAHAT IS THE PROBABILITY THAT
#lam=rate of known occurences of the event
x= random.poisson(lam=2,size=7)
print(x)
# Out:
# [3 3 2 2 0 1 1]

# %%
sns.displot(random.poisson(lam=2,size=1000),kde=False)
plt.show()

# %%
#uniform distribution
# every event has equal chance of appearing
#E.G generation of random number
x=random.uniform(size=(2,3))
print(x)
# Out:
# [[0.34108591 0.22119703 0.18713844]
#  [0.09412126 0.1353417  0.23068866]]

# %%
sns.displot(random.uniform(size=1000),kde=True)
plt.show()

# %%
#MULTINOMIAL DISTRIBUTION
#Here any event has more than two possible outcomes
x=random.multinomial(n=20,pvals=[1/6,1/6,1/6,1/6,1/6,1/6])
print(x)
# Out:
# [3 3 1 1 5 7]

# %%
sns.displot(random.multinomial(n=20,pvals=[1/6,1/6,1/6,1/6,1/6,1/6]))
plt.show()

# %%
from numpy import random
x=random.exponential(scale=2,size=(2,3))
print(x)
# Out:
# [[1.44440201 3.25018538 0.67752038]
#  [0.87293246 5.12354762 2.54582905]]

# %%
sns.displot(np.random.exponential(size=100))
plt.show()

# %%
from numpy import random
x=random.rayleigh(size=100)
print(x)
# Out:
# [0.92051778 1.73031444 1.64679704 0.16159109 1.07046582 0.77438897
#  2.52109481 0.53534174 2.47594121 0.67071937 1.63874345 1.51088465
#  1.44808984 1.1453858  0.7585281  1.79076828 1.01149092 0.85144229
#  1.54682549 1.58078724 1.38941623 0.89313253 1.57531787 1.23121546
#  1.74147223 0.72714693 0.0649573  0.70711066 1.00301966 0.37408399
#  1.04584349 1.19350666 0.46915676 0.72019192 0.69557453 1.07804316
#  2.22162997 1.00238484 1.40119356 1.38254928 2.36778593 1.81267098
#  0.95982724 0.95989678 0.63962584 1.41140899 2.96171572 0.73096712
#  1.43004024 1.28935761 1.058107   0.66777851 1.26525825 2.89642407
#  1.13218939 1.42050883 2.1027607  1.39727788 0.26668182 1.50272137
#  1.3923997  1.03790918 0.66127005 2.09280295 1.15263034 0.4212692
#  1.05345511 2.23394853 1.93955531 2.10212173 0.97601055 0.25887412
#  0.93605517 1.42650212 1.57174073 1.23706723 0.88282495 2.49853585
#  1.46219212 1.38383363 0.67990588 0.59953752 0.85185093 0.99183288
# ...

# %%
sns.displot(np.random.rayleigh(size=100), kde=True)
plt.show()

# %%
# %pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # 21 AUGUST 2026

# %% [markdown]
# # EXP 4 READIND SEVERAL TYPES OF DATASET FROM THE WEB AND DISK AND WRITING IN A FILE SPECIFIC DISK LOCATION

# %%
# syntax---->rule---->write a function?code
#variable_name=open(file name,mode)
#Mode---> r: read
#Mode--->w: write---->override the existing file
#Mode--->a: append
#Mode--->r+: read and write (override the existing file)
#Mode---->w+: write---->read (override the existing file)
#Mode--->a+: appedn (won't ovverride the file)
#mode--->x: Create specific file returns error if the file exists

# %%
f=open("C:\\Users\\Priya Rani\\Desktop\\student.txt","r")
print(f.read())
f.close()
# Out:
# hello world bjuhkjnijhnkj

# %%
#reading the first five character of the file
f=open("C:\\Users\\Priya Rani\\Desktop\\student.txt","r")
print(f.read(5))
f.close()
# Out:
# hello

# %%
#read two lines of the file
f=open("C:\\Users\\Priya Rani\\Desktop\\example.txt","r")
print(f.readline())
print(f.readline())
f.close()
# Out:
# This

# %%
#Read file line by line
f=open("C:\\Users\\Priya Rani\\Desktop\\student.txt","r")
for x in f:
    print(x)
f.close()
# Out:
# hello world bjuhkjnijhnkj

# %%
# Read the content of the file
path="C:\\Users\\Priya Rani\\Desktop\\student.txt"
file=open(path)
content=file.readlines()
print(content[1])
#print(content[2])
#print(content[3])
print(content[4])
file.close()
# Out:
# apple
#
# black berry

# %%
#CREATE A FILE USING "W".
file=open("C:\\Users\\Priya Rani\\Desktop\\example.txt","w")
file.write("This is the first line")
file.write("\n This is the second line")
file.write("\n This is the third line")
file.write("\n This is the fourth line")
file.close()

# %%
import os 
if os.path.exists("cretefile.txt"):
    os.remove("cretefile1.txt")
else:
    print("no file found")
# Out:
# no file found

# %%
#Deletion of a file
import os 
if os.path.exists("cretefile.txt"):
    os.remove("cretefile1.txt")
else:
    print("no file found")
# Out:
# no file found

# %%
# split function ---> function used to split the word
path="C:\\Users\\Priya Rani\\Desktop\\student.txt"
with open(path,"r") as file:
# data=all the lines of file
 data=file.readlines()

#in line(varibale)----> store the information received from data(varibale)
for line in data:
 word=line.split()
print(word)
# Out:
# ['guava']

# %% [markdown]
# # PANDAS

# %%
# %pip install pandas
import pandas as pd
print(pd.__version__)
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# 3.0.5

# %%
#dictionary---> D.S---consists--->key-value pair
mydataset={
    'cars':["BMW","MARUTI","HONDA","KTA"],
    'PASS':[2,5,5,7]
}
#SYNTAX for dictionary
#dictionary_name={
#'name_of_key'=[values]
#}
myvar=pd.DataFrame(mydataset)
print(myvar)
# Out:
#      cars  PASS
# 0     BMW     2
# 1  MARUTI     5
# 2   HONDA     5
# 3     KTA     7

# %%
#Create a simple panda Series from a list
import pandas as pd
a=[1,7,8,10]
myvar=pd.Series(a)
print(myvar[3])
# Out:
# 10

# %%
#Create the label(that describes the data)
import pandas as pd
a=[1,7,8,10]
myvar=pd.Series(a,index=["S.no","marks","Grade","Age"])
print(myvar["Age"])
# Out:
# 10

# %%
# Pandas Series from a dictionary
calories={"day1":30,"day2":120,"day3":300}
sr=pd.Series(calories)
print(sr)
# Out:
# day1     30
# day2    120
# day3    300
# dtype: int64

# %%
#DATA FRAME
import pandas as pd
data={
    "calories":[100,200,300],
    "hour":[1,2,3]
}
df=pd.DataFrame(data)
print(df)
# Out:
#    calories  hour
# 0       100     1
# 1       200     2
# 2       300     3

# %% [markdown]
# # extra

# %%
# Read the content of the file
path="C:\\Users\\Priya Rani\\Desktop\\student.txt"
file=open(path)
content=file.readlines()
print(content)
file.close()
# Out:
# ['hello world bjuhkjnijhnkj']

# %%
f=open("C:\\Users\\Priya Rani\\Desktop\\student.txt","r")
print(f.read())
f.close()
# Out:
# hello world bjuhkjnijhnkj
# apple
# mango
# grapes
# black berry
# guava

# %% [markdown]
# # 28 AUGUST

# %% [markdown]
# # DATA CLEANING

# %%
#DIRTY DATA (UNCLEANED DATA):
#MISSING DATAANED DATA)

# %%
import pandas as pd
df=pd.read_csv(r"C:\\Users\\Priya Rani\\Desktop\\PRACTICE C\\dirtydata\\dirtydata.csv")
print(df)
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
print(df)
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  32 non-null     int64
#  1   Date      31 non-null     str
#  2   Pulse     32 non-null     int64
#  3   Maxpulse  32 non-null     int64
#  4   Calories  30 non-null     float64
# dtypes: float64(1), int64(3), str(1)
# memory usage: 1.4 KB

# %%
# Describing the data
#describe()--function--->describes the data
print(df.describe())
# Out:
#          Duration       Pulse    Maxpulse    Calories
# count   32.000000   32.000000   32.000000   30.000000
# mean    68.437500  103.500000  128.500000  304.680000
# std     70.039591    7.832933   12.998759   66.003779
# min     30.000000   90.000000  101.000000  195.100000
# 25%     60.000000  100.000000  120.000000  250.700000
# 50%     60.000000  102.500000  127.500000  291.200000
# 75%     60.000000  106.500000  132.250000  343.975000
# max    450.000000  130.000000  175.000000  479.000000

# %%
# to see first rows and columns of data 
print(df.head(3))
# Out:
#    Duration          Date  Pulse  Maxpulse  Calories
# 0        60  '2020/12/01'    110       130     409.1
# 1        60  '2020/12/02'    117       145     479.0
# 2        60  '2020/12/03'    103       135     340.0

# %%
# to see first rows and columns of data 
print(df.tail(3))
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 29        60  '2020/12/29'    100       132     280.0
# 30        60  '2020/12/30'    102       129     380.3
# 31        60  '2020/12/31'     92       115     243.0

# %%
# convert the dataframe to string 
new_df=(df.to_string())
print(new_df)
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7         45  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# 16        60  '2020/12/16'     98       120     215.2
# ...

# %%
# Drop the NaN values
new_df=(df.to_string())
print(new_df)
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %% [raw]
# # Drop the NaN values
# # variable_name=dataframe.dropna()
# new_df=(df.to_dropna())
# print(new_df)

# %%
# change the origional file
df.dropna(inplace=True)
print(df)
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
# change the origional file
# Inplace----deletes----->origional data
df.dropna(inplace=True)
print(df)
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
# Verify the data
df.loc[7,'Duration']
# Out:
# np.int64(450)

# %%
# Re alocate the value with the new one
df.loc[7,'Duration']=45

# %%
# Rules
# it see and check every row and column and store the vaue at...
# variable x
for x in df.index:
    if df.loc[x,"Duration"]> 120:
        df.loc[x,"Duration"]= 120
        
print(df)
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7         45  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
# Rules
# it see and check every row and column and store the vaue at...
# variable x
for x in df.index:
    if df.loc[x,"Maxpulse"]> 120:
           df.loc[x,"Maxpulse"]= 120
print(df)
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       120     409.1
# 1         60  '2020/12/02'    117       120     479.0
# 2         60  '2020/12/03'    103       120     340.0
# 3         45  '2020/12/04'    109       120     282.4
# 4         45  '2020/12/05'    117       120     406.0
# 5         60  '2020/12/06'    102       120     300.0
# 6         60  '2020/12/07'    110       120     374.0
# 7         45  '2020/12/08'    104       120     253.3
# 8         30  '2020/12/09'    109       120     195.1
# 9         60  '2020/12/10'     98       120     269.0
# 10        60  '2020/12/11'    103       120     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       120     345.3
# 14        60  '2020/12/14'    104       120     379.3
# 15        60  '2020/12/15'     98       120     275.0
# ...

# %%
# Rules
# it see and check every row and column and store the vaue at...
# variable x
# go it dataframe(df) and check its index------> x row and col (1,1)
for x in df.index:
    # check if in dataframe (df)--->loc(x) and rowname> 120:
    if df.loc[x,"Duration"]> 120:
        # set the value as 120
           df.loc[x,"Duration"]= 120
print(df)
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       120     409.1
# 1         60  '2020/12/02'    117       120     479.0
# 2         60  '2020/12/03'    103       120     340.0
# 3         45  '2020/12/04'    109       120     282.4
# 4         45  '2020/12/05'    117       120     406.0
# 5         60  '2020/12/06'    102       120     300.0
# 6         60  '2020/12/07'    110       120     374.0
# 7         45  '2020/12/08'    104       120     253.3
# 8         30  '2020/12/09'    109       120     195.1
# 9         60  '2020/12/10'     98       120     269.0
# 10        60  '2020/12/11'    103       120     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       120     345.3
# 14        60  '2020/12/14'    104       120     379.3
# 15        60  '2020/12/15'     98       120     275.0
# ...

# %%
# Rule for Deletion
for x in df.index:
    if df.loc[x,"Duration"]>120:
        df.drop(x, inplace=True)

# %%
# Drop the duplicate value
nv=df.duplicated()
print(nv)
new_out=df.loc[nv==True]
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12     True
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 19    False
# 20    False
# 21    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 29    False
# 30    False
# 31    False
# dtype: bool

# %%
# Drop the duplicate value
# variable name=dataframe(df)---> duplicated()---function---check---Duplicated()------return------Boolean value
nv=df.duplicated()
print(nv)
# Checking where the duplicates values lies??----lies-----nv---becomes---True
new_out=df.loc[nv==True]
print(new_out)
#drop_duplicates----function----drop---Duplicate
df.drop_duplicates(inplace=True)
print(df.to_string())
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12     True
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# dtype: bool
#     Duration          Date  Pulse  Maxpulse  Calories
# 12        60  '2020/12/12'    100       120     250.7
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# ...

# %%
import pandas as pd
import numpy as np
# Creating a dictionary--->{key:values}---key---F.S---value-->
dict={'First Score':[100,90,np.nan,95],
      'Second Score':[np.nan,45,56,np.nan],
     'Third Score':[np.nan,40,80,95]
     }
df=pd.DataFrame(dict)
print(df)
print(df.to_string())
# Out:
#    First Score  Second Score  Third Score
# 0        100.0           NaN          NaN
# 1         90.0          45.0         40.0
# 2          NaN          56.0         80.0
# 3         95.0           NaN         95.0
#    First Score  Second Score  Third Score
# 0        100.0           NaN          NaN
# 1         90.0          45.0         40.0
# 2          NaN          56.0         80.0
# 3         95.0           NaN         95.0

# %%
# CHECK IF THE VALUE IS NULL OR NOT
print(df.isnull())
# Out:
#    First Score  Second Score  Third Score
# 0        False          True         True
# 1        False         False        False
# 2         True         False        False
# 3        False          True        False

# %%
# CHECK IF THE VALUE IS NOT NULL 
print(df.notnull())
# Out:
#    First Score  Second Score  Third Score
# 0         True         False        False
# 1         True          True         True
# 2        False          True         True
# 3         True         False         True

# %%
# Fillinf up the missing value
print(df.replace(to_replace=np.nan,value=40))
# Out:
#    First Score  Second Score  Third Score
# 0        100.0          40.0         40.0
# 1         90.0          45.0         40.0
# 2         40.0          56.0         80.0
# 3         95.0          40.0         95.0

# %%
# Replace the NaN values with the mean
df_mean=df.mean()
print(df_mean)
# fillna----Function--->fill the NaN--->users choice of value
data_new=df.fillna(df.mean())
print(data_new)
# Out:
# First Score     95.000000
# Second Score    50.500000
# Third Score     71.666667
# dtype: float64
#    First Score  Second Score  Third Score
# 0        100.0          50.5    71.666667
# 1         90.0          45.0    40.000000
# 2         95.0          56.0    80.000000
# 3         95.0          50.5    95.000000

# %%
import numpy as np

# %%
# CHECK IF THE VALUE IS NOT NULL 
print(df.notnull())
# Out:
#    First Score  Second Score  Third Score
# 0         True         False        False
# 1         True          True         True
# 2        False          True         True
# 3         True         False         True

# %%
import pandas as pd
df=pd.read_csv(r"C:\\Users\\Priya Rani\\Desktop\\PRACTICE C\\dirtydata\\dirtydata.csv")
print(df)
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
# %pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

df=pd.read_csv(r"C:\\Users\\Priya Rani\\Desktop\\PRACTICE C\\dirtydata\\dirtydata.csv")
print(df)
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %% [markdown]
# # 04 september 2026

# %% [markdown]
# # LAB 6

# %% [markdown]
# # USE MATPLOTLIB LIBRARY TO VISUALIZE LINE,SCATTER,BAR CHART,HISTOGRAM,PIE BOX/WISHKER PLOT

# %%
#LINE PLOT
import matplotlib.pyplot as plt
import numpy as np
xpoints=np.array([1,8])
ypoints=np.array([3,10])
plt.plot(xpoints,ypoints)
plt.show()

# %%
#LINE PLOT
import matplotlib.pyplot as plt
import numpy as np
xaxis=np.array([1,8])
yaxis=np.array([3,10])
plt.plot(xaxis,yaxis)
plt.show()

# %%
# Draw a line with default x-axis starting with 0
ypoints=np.array([3,8,1,10,5,7])
#ypoints-->y axis data
# ls--->line style
#lw---->line width
#ms----->marker size
#mec---->marker edge color
#mfc----->marker face color
plt.plot(ypoints,marker='o', ls="--",lw='2',ms=20,mec='r',mfc='y')

# %%
# Draw a line with default x-axis starting with 0
ypoints=np.array([3,8,1,10,5,7])
#ypoints-->y axis data
# ls--->line style
#lw---->line width
#ms----->marker size
#mec---->marker edge color
#mfc----->marker face color
plt.plot(ypoints,marker='*', ls="--",lw='2',ms=20,mec='r',mfc='y')

# %%
ypoints=np.array([3,8,1,10,5,7])
plt.plot(ypoints,marker='*', ls="--",lw='2',ms=20,mec='r',mfc='y')

# %%
# Draw a line with default x-axis starting with 0
ypoints=np.array([3,8,1,10,5,7])
#ypoints-->y axis data
# ls--->line style
#lw---->line width
#ms----->marker size
#mec---->marker edge color
#mfc----->marker face color
plt.plot(ypoints,marker='*', ls="--",lw='2',ms=200,mec='r',mfc='y')

# %% [raw]
# # Draw a line with default x-axis starting with 0
# ypoints=np.array([3,8,1,10,5,7])
# #ypoints-->y axis data
# # ls--->line style
# #lw---->line width
# #ms----->marker size
# #mec---->marker edge color
# #mfc----->marker face color
# plt.plot(ypoints,marker='o', ls="--",lw='2',ms=20,mec='g',mfc='y')

# %%
# Draw a line with default x-axis starting with 0
ypoints=np.array([3,8,1,10,5,7])
#ypoints-->y axis data
# ls--->line style
#lw---->line width
#ms----->marker size
#mec---->marker edge color
#mfc----->marker face color
plt.plot(ypoints,marker='*', ls="--",lw='2',ms=20,mec='r',mfc='r')

# %%
# Draw two line by specifying a plt.plot() for each line
import matplotlib.pyplot as plt
import numpy as np
y1=np.array([3,8,1,10])
y2=np.array([6,2,1,11])
plt.plot(y1)
plt.plot(y2)
plt.show()

# %%
# draw two lines by specifying both x and y
x1=np.array([0,1,2,3])
y1=np.array([3,8,1,10])
x2=np.array([0,1,2,3])
y2=np.array([6,2,7,11])
plt.plot(x1,y1,x2,y2)
plt.show()

# %%
x=np.array([80,85,90,95,100,105,110,115,120,125])
y=np.array([240,250,260,270,280,290,300,310,320,330])
# COUTION----> MAKE SURE THAT THE X AND Y ARE OF SAME SIZE
plt.plot(x,y,'o:r',mfc='b')
plt.title("Exercise data",loc='center')
plt.xlabel("Duration")
plt.ylabel("Calories burnt")
plt.show()

# %%
# Font Properties
font1={'family':'serif','color':'blue','size':20}
font2={'family':'serif','color':'red','size':20}
plt.plot(x,y,'o:g',mfc='b')
plt.title("Sports Data New",fontdict=font1)
plt.xlabel("Hours",fontdict=font2)
plt.xlabel("Calories",fontdict=font1)
plt.grid()
plt.grid(axis='x')
plt.grid(axis='y')
plt.grid(color='green',linestyle="--",linewidth=0.5)
plt.show()

# %%
# use subplot
plt.subplot(2,1,1)
plt.plot(x1,y1)
plt.subplot(2,1,2)
plt.plot(x2,y2)
plt.show()

# %%
# SCATTER PLOT
# day one, the age and the speed of 13 cars

x1=np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y1=np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

# random---> generate random data
# randint-----> generate the random integer
# 13-----> return item(integer must be of size 13
# out of 100 items select 13 items at random

colors=np.random.randint(100,size=(13))
size=2*np.random.randint(100,size=(13))

plt.subplot(2,3,1)

# alpha--> control the transparency
plt.scatter(x1,y1,c=colors,s=size,alpha=0.3,cmap="nipy_spectral")


# Day 2
x2=np.array([2,2,8,1,15,8,12,11,10,5,14,1,4])
y2=np.array([100,105,110,88,84,85,90,95,100,70,107,84,83])

plt.subplot(2,3,2)
plt.scatter(x2,y2,color='r')


## Multiple scatter plot in a single plot

plt.subplot(2,3,3)
plt.scatter(x1,y1,color='b')

plt.subplot(2,3,3)
plt.scatter(x2,y2,color='r')


# set own colors

colors=np.array(["red","green","blue","purple","beige","magenta","yellow","black","pink","orange","cyan","gray","brown"])

plt.subplot(2,3,4)
plt.scatter(x1,y1,c=colors)


# Create a color array and specify a colormap in the scatter plt

colors=np.array([0,10,20,30,40,45,50,55,60,70,80,90,100])

plt.subplot(2,3,5)
plt.scatter(x1,y1,c=colors,cmap='viridis')

plt.show()

# %%
# Bar plot
x=np.array(["A","B","C","D"])
y=np.array([3,8,1,10])
plt.subplot(2,1,1)
plt.bar(x,y,width=0.2)
# Out:
# <BarContainer object of 4 artists>

# %%
# Bar plot
x=np.array(["A","B","C","D"])
y=np.array([3,8,1,10])
plt.subplot(2,1,1)
plt.bar(x,y,width=0.2)
plt.subplot(2,1,2)
plt.barh(x,y,color="red",height=0.5)
# Out:
# <BarContainer object of 4 artists>

# %%
# Histogram
x=np.random.normal(170,10,250)
plt.hist(x)
plt.xlabel("Height of person in cm")
plt.ylabel("Number of people")
plt.show()

# %%
# PIE CHART
y=np.array([35,25,25,15])
mylabels=["Apple","Banana","kiwi","Blueberry"]
plt.subplot(3,2,1)
plt.pie(y,labels=mylabels)
plt.subplot(3,2,2)
plt.pie(y,labels=mylabels,startangle=90)
plt.subplot(3,2,3)
myexplode=[0.2,0,0,0]
plt.pie(y,labels=mylabels,explode=myexplode)
plt.subplot(3,2,4)
plt.pie(y,labels=mylabels,explode=myexplode,shadow=True)
plt.subplot(3,2,5)
plt.pie(y,labels=mylabels)
plt.legend(title="Four Fruits")
plt.show()

# %%
# BOX PLOT
# Create a data
data_1=np.random.normal(100,10,200)
data_2=np.random.normal(90,20,200)
data_3=np.random.normal(80,30,200)
data_4=np.random.normal(70,40,200)
data=[data_1,data_2,data_3,data_4]
fig=plt.figure(figsize=(10,7))
ax=fig.add_axes([0,0,1,1])
bp=ax.boxplot(data)
plt.show()
