# %%
print("hello world")
# Out:
# hello world

# %%
a=2
b=3
sum=a+b
print(f"sumis:{sum}")
# Out:
# sumis:5

# %%
a=9
b=3
sub=a-b
print(f"subis:{sub}")
# Out:
# subis:6

# %%
a=2
b=3
num=a*b
print(f"mul is:{num}")
# Out:
# mul is:6

# %%
a=9
b=3
num=a/b
print(f"divide is:{num}")
# Out:
# divide is:3.0

# %%
a=9
b=3
num=a%b
print(f"remainder is:{num}")
# Out:
# remainder is:0

# %%
a=2
b=3
c=4
det=(b*b)-(4*a*c)
print(f"det is:{det}")
# Out:
# det is:-23

# %%
p=4500
r=2
t=1
simple=(p*r*t)/100
print(f"interest is:{simple}")
# Out:
# interest is:90.0

# %%
celcius=45
farenheit=(9/5*celcius)+32
print(f"temperature is:{farenheit}")
# Out:
# temperature is:113.0

# %%
celsius = float(input("Enter temperature in Celsius: "))
farenheit=(9/5*celcius)+32
print(f"temperature is:{farenheit}")
